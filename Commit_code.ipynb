# %%
from google.colab import drive
import os
import shutil

# Google Drive 마운트
drive.mount('/content/drive')

# 작업 디렉토리 이동
# %cd /content/drive/MyDrive/trade_data_analysis

# 환경 변수 설정
os.environ['GITHUB_TOKEN'] = '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'

# 저장소 클론
# !git clone https://{os.getenv('GITHUB_TOKEN')}@github.com/Leejoowon123/Colab_analysis.git

# 클론된 디렉토리로 이동
# %cd Colab_analysis/

# Git 설정
# !git config --global user.email 'joowon582@gmail.com'
# !git config --global user.name 'Leejoowon123'

# 파일 복사 함수 정의
def copy_files(src_dir, dst_dir):
    for item in os.listdir(src_dir):
        s = os.path.join(src_dir, item)
        d = os.path.join(dst_dir, item)
        if os.path.isdir(s):
            shutil.copytree(s, d, dirs_exist_ok=True)
        else:
            shutil.copy2(s, d)

# /content/drive/MyDrive/trade_data_analysis에 있는 모든 파일을 Colab_analysis 폴더로 복사
src_dir = "/content/drive/MyDrive/trade_data_analysis"
dst_dir = "/content/drive/MyDrive/trade_data_analysis/Colab_analysis"
copy_files(src_dir, dst_dir)

# Colab_analysis 디렉토리로 이동
# %cd /content/drive/MyDrive/trade_data_analysis/Colab_analysis

# 파일을 추가, 커밋, 푸시하는 함수 정의
def commit_and_push(commit_message):
    # 모든 변경사항 추가
    # !git add -A

    # 커밋
    # !git commit -m "{commit_message}"

    # 푸시
    # !git push https://{os.getenv('GITHUB_TOKEN')}@github.com/Leejoowon123/Colab_analysis.git

# 예제 커밋 메시지로 커밋 및 푸시 실행
commit_and_push("Add all files from trade_data_analysis")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/trade_data_analysis
# fatal: destination path 'Colab_analysis' already exists and is not an empty directory.
# /content/drive/MyDrive/trade_data_analysis/Colab_analysis
# /content/drive/MyDrive/trade_data_analysis/Colab_analysis
# [main 4e30817] Add all files from trade_data_analysis
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite Untitled1.ipynb (91%)
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 2.48 KiB | 281.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Leejoowon123/Colab_analysis.git
#    d3a6999..4e30817  main -> main

# %%
# 파일 삭제 및 이름 변경
os.remove('/content/drive/MyDrive/trade_data_analysis/Untitled0.ipynb')  # 파일 삭제
os.rename('/content/drive/MyDrive/trade_data_analysis/Untitled.ipynb', '/content/drive/MyDrive/trade_data_analysis/Commit_code.ipynb')  # 파일 이름 변경

# 예제 커밋 메시지로 커밋 및 푸시 실행
commit_and_push("Delete a file, rename another, and commit all changes")
