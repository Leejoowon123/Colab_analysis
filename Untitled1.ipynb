# %%
from google.colab import drive
import os

# Google Drive 마운트
drive.mount('/content/drive')

# 작업 디렉토리 이동
# %cd /content/drive/MyDrive/trade_data_analysis

# 환경 변수 설정
os.environ['GITHUB_TOKEN'] = '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'

# 저장소 클론
# !git clone https://{os.getenv('GITHUB_TOKEN')}@github.com/Leejoowon123/Colab_analysis.git

# 클론된 디렉토리로 이동
# %cd Colab_analysis/

# Git 설정
# !git config --global user.email 'joowon582@gmail.com'
# !git config --global user.name 'Leejoowon123'

# 파일을 추가, 커밋, 푸시하는 함수 정의
def commit_and_push(commit_message):
    # 모든 변경사항 추가
    # !git add -A

    # 커밋
    # !git commit -m "{commit_message}"

    # 푸시
    # !git push https://{os.getenv('GITHUB_TOKEN')}@github.com/Leejoowon123/Colab_analysis.git

# 예제 커밋 메시지로 커밋 및 푸시 실행
commit_and_push("Initial commit from Colab")
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/trade_data_analysis
# Cloning into 'Colab_analysis'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.
# /content/drive/MyDrive/trade_data_analysis/Colab_analysis
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
