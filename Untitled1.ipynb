# %%
from google.colab import drive
import os
import shutil

# Google Drive 마운트
drive.mount('/content/drive')

# 작업 디렉토리 이동
# %cd /content/drive/MyDrive/trade_data_analysis

# 환경 변수 설정
os.environ['GITHUB_TOKEN'] = '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'

# 저장소 클론
# !git clone https://{os.getenv('GITHUB_TOKEN')}@github.com/Leejoowon123/Colab_analysis.git

# 클론된 디렉토리로 이동
# %cd Colab_analysis/

# Git 설정
# !git config --global user.email 'joowon582@gmail.com'
# !git config --global user.name 'Leejoowon123'

# 파일 복사 함수 정의
def copy_files(src_dir, dst_dir):
    for item in os.listdir(src_dir):
        s = os.path.join(src_dir, item)
        d = os.path.join(dst_dir, item)
        if os.path.isdir(s):
            shutil.copytree(s, d, dirs_exist_ok=True)
        else:
            shutil.copy2(s, d)

# /content/drive/MyDrive/trade_data_analysis에 있는 모든 파일을 Colab_analysis 폴더로 복사
src_dir = "/content/drive/MyDrive/trade_data_analysis"
dst_dir = "/content/drive/MyDrive/trade_data_analysis/Colab_analysis"
copy_files(src_dir, dst_dir)

# Colab_analysis 디렉토리로 이동
# %cd /content/drive/MyDrive/trade_data_analysis/Colab_analysis

# 파일을 추가, 커밋, 푸시하는 함수 정의
def commit_and_push(commit_message):
    # 모든 변경사항 추가
    # !git add -A

    # 커밋
    # !git commit -m "{commit_message}"

    # 푸시
    # !git push https://{os.getenv('GITHUB_TOKEN')}@github.com/Leejoowon123/Colab_analysis.git

# 예제 커밋 메시지로 커밋 및 푸시 실행
commit_and_push("Add all files from trade_data_analysis")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/trade_data_analysis
# fatal: destination path 'Colab_analysis' already exists and is not an empty directory.
# /content/drive/MyDrive/trade_data_analysis/Colab_analysis
# /content/drive/MyDrive/trade_data_analysis/Colab_analysis
# warning: adding embedded git repository: Colab_analysis
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> Colab_analysis
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached Colab_analysis
# hint:
# hint: See "git help submodule" for more information.
# [main d3a6999] Add all files from trade_data_analysis
#  19 files changed, 494247 insertions(+)
#  create mode 160000 Colab_analysis
#  create mode 100644 PredictPrice.ipynb
#  create mode 100644 Untitled0.ipynb
#  create mode 100644 Untitled1.ipynb
#  create mode 100644 start.ipynb
#  create mode 100644 "\341\204\200\341\205\252\341\206\274\341\204\214\341\205\251\341\206\274 \341\204\211\341\205\256\341\204\216\341\205\256\341\206\257\341\204\213\341\205\265\341\206\270 \341\204\222\341\205\247\341\206\253\341\204\222\341\205\252\341\206\274.csv"
#  create mode 100644 "\341\204\200\341\205\252\341\206\274\341\204\214\341\205\251\341\206\274\341\204\207\341\205\247\341\206\257 \341\204\200\341\205\256\341\206\250\341\204\200\341\205\241\341\204\207\341\205\247\341\206\257 \341\204\211\341\205\242\341\206\274\341\204\211\341\205\241\341\206\253\341\204\205\341\205\243\341\206\274.csv"
#  create mode 100644 "\341\204\200\341\205\252\341\206\274\341\204\214\341\205\251\341\206\274\341\204\207\341\205\247\341\206\257 \341\204\211\341\205\251\341\204\207\341\205\265\341\204\222\341\205\247\341\206\253\341\204\222\341\205\252\341\206\274.csv"
